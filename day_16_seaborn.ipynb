# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
tip = sns.load_dataset('tips')            #load data
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.histplot(tip["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.kdeplot(tip["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
sns.relplot(x="total_bill",y="tip",data=tip,kind ="line")

# %%
sns.relplot(x="total_bill",y="tip",data=tip)

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time")

# %%
sns.relplot(x="total_bill",y="tip",data=tip,kind="line",hue= "time")

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time",style='smoker')         #hue change colour with different graph

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time",style='smoker',col='time')

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time",style='smoker',col='smoker')

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time",style='smoker',col='day')

# %%
sns.relplot(x="total_bill",y="tip",data=tip,hue= "time",style='smoker',row='day')

# %%
sns.catplot(x= "day",y="total_bill",data=tip)

# %%
sns.catplot(x= "day",y="total_bill",data=tip,kind='violin')

# %%
plt.figure(figsize=(5,5))
sns.countplot(tip['day'])
# Out:
# <Axes: xlabel='count', ylabel='day'>

# %%
sns.boxenplot(tip['day'])
# Out:
# <Axes: ylabel='day'>

# %%
sns.boxenplot(tip['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
sns.boxplot(tip['total_bill'])
# Out:
# <Axes: ylabel='total_bill'>

# %%
tip.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sorted_total_bill=tip.sort_values(by = "total_bill")['total_bill']
sorted_total_bill
# Out:
# 67      3.07
# 92      5.75
# 111     7.25
# 172     7.25
# 149     7.51
#        ...
# 182    45.35
# 156    48.17
# 59     48.27
# 212    48.33
# 170    50.81
# Name: total_bill, Length: 244, dtype: float64

# %% [markdown]
# #dealing with outlliers
# #1 = remove
# #2 = scaqle of transform

# %%
upper_limit = tip['total_bill'].quantile()

# %%
sns.boxplot(tip[tip['total_bill']<upper_limit]["total_bill"])
# Out:
# <Axes: ylabel='total_bill'>

# %% [markdown]
# # using IQR range

# %%
q1 = np.percentile(tip["total_bill"],25)     # IQR range 25 to 75 and 25 mean q1 or 75 mean q3
q3 = np.percentile(tip["total_bill"],75)
IQR = q2-q1
upper_limit = q3+1.5*IQR
lower_limit = q1-1.5*IQR

# %%
q1  = np.percentile(tip["total_bill"],25)
q1
# Out:
# 13.3475

# %%
IQR
# Out:
# 10.779999999999998

# %%
upper_limit = q3+1.5*IQR
lower_limit = q1-1.5*IQR

# %%
q3  = np.percentile(tip["total_bill"],75)
q3
# Out:
# 24.127499999999998

# %%
upper_limit = q3+1.5*IQR

# %%
lower_limit = q1-1.5*IQR
